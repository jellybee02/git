# %%
from sklearn.datasets import fetch_olivetti_faces

digits = fetch_olivetti_faces()
X = digits.data  # Image data
y = digits.target # Target labels (the digit value)

print(X.shape) # Output: (1797, 64) for 1797 images, each 8x8 pixels flattened
print(y.shape) # Output: (1797,)
# Out:
# (400, 4096)
# (400,)

# %%
X = X.reshape(-1, 64, 64)  # Reshape to (1797, 8, 8) for image format
print(X.shape) # Output: (1797, 8, 8)
# Out:
# (400, 64, 64)

# %%
# Out:
# array([[[0.30991736, 0.3677686 , 0.41735536, ..., 0.37190083,
#          0.3305785 , 0.30578512],
#         [0.3429752 , 0.40495867, 0.43801653, ..., 0.37190083,
#          0.338843  , 0.3140496 ],
#         [0.3429752 , 0.41735536, 0.45041323, ..., 0.38016528,
#          0.338843  , 0.29752067],
#         ...,
#         [0.21487603, 0.20661157, 0.2231405 , ..., 0.15289256,
#          0.16528925, 0.17355372],
#         [0.20247933, 0.2107438 , 0.2107438 , ..., 0.14876033,
#          0.16115703, 0.16528925],
#         [0.20247933, 0.20661157, 0.20247933, ..., 0.15289256,
#          0.16115703, 0.1570248 ]],
#
#        [[0.45454547, 0.47107437, 0.5123967 , ..., 0.19008264,
#          0.18595041, 0.18595041],
#         [0.446281  , 0.48347107, 0.5206612 , ..., 0.21487603,
#          0.2107438 , 0.2107438 ],
#         [0.49586776, 0.5165289 , 0.53305787, ..., 0.20247933,
#          0.20661157, 0.20661157],
#         ...,
#         [0.77272725, 0.78099173, 0.7933884 , ..., 0.1446281 ,
# ...

# %%
len(y)
# Out:
# 400
